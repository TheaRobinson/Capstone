# %%
import pandas as pd

### Get Data
# Get Parcel ID Data
parcel_id = pd.read_csv("MKE_Parcel_ID.csv", encoding = 'latin-1', sep = ',')

# Get MPROP Data
mprop_19 = pd.read_csv("MPROP_2019.csv", encoding = 'latin-1', sep = ',')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Clean Data
data_19 = mprop_19[['HOUSE_NR_LO', 'SDIR', 'STREET', 'STTYPE', 'OWN_OCPD', 'P_A_LAND', 'P_A_IMPRV', 'P_A_TOTAL', 'GEO_TRACT']]
data_19['OWN_OCPD'] = data_19['OWN_OCPD'].fillna('N')
data_19['address'] = data_19['HOUSE_NR_LO'].map(str) + ' ' + data_19['SDIR'].map(str) + ' ' + \
    data_19['STREET'].map(str) + ' ' + data_19['STTYPE'].map(str)


data_19['imprv_val_share'] = data_19['P_A_IMPRV'] / data_19['P_A_TOTAL']
data_19['imprv_val_share'] = data_19['imprv_val_share'].fillna(-1)

tract_19 = data_19[['GEO_TRACT', 'imprv_val_share', 'P_A_TOTAL', 'P_A_LAND']]

tract_19 = tract_19.groupby(['GEO_TRACT']).median()

tract_19
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_19
# Out:
#         HOUSE_NR_LO SDIR   STREET STTYPE OWN_OCPD  P_A_LAND  P_A_IMPRV  \
# 0              2263    N     LAKE     DR        N         0          0
# 1              9164    N     70TH     ST        N         0          0
# 2              8919    N     70TH     ST        N         0          0
# 3              9036    N     70TH     ST        N         0          0
# 4              9083    N     85TH     ST        N         0          0
# ...             ...  ...      ...    ...      ...       ...        ...
# 160599         1701    E  COLLEGE     AV        N    165600    3834400
# 160600         1701    E  COLLEGE     AV        N         0          0
# 160601         6757    S     13TH     ST        N    501400     942000
# 160602         6719    S     13TH     ST        N    616000    2517600
# 160603         6801    S     13TH     ST        N   1010000    1702300
#
#         P_A_TOTAL  GEO_TRACT            address  imprv_val_share
# ...

# %%
parcel_id
# Out:
#         parcelnumb                           owner               address
# 0     3.240809e+09                    CITY OF MILW        2660 N 17TH ST
# 1     3.522824e+09               CITY OF MILWAUKEE        1909 N 14TH ST
# 2     3.113115e+09               VALERIA G GRIFFIN        2859 N 14TH ST
# 3     3.513802e+09                    WILMA SMILEY  1350 W RESERVOIR AVE
# 4     3.231432e+09                  BARBARA J BLUE         2358 N 9TH ST
# ...            ...                             ...                   ...
# 2481           NaN  incomplete taxroll information                   NaN
# 2482           NaN  incomplete taxroll information                   NaN
# 2483  3.121209e+09              CONSTANCE A HOLMAN        2740 N 10TH ST
# 2484  3.231510e+09       GEOFFREY R ZOLLIKOFFER II         2663 N 8TH ST
# 2485  3.241043e+09                    LORN BLACKER      1725 W CLARKE ST
#
# [2486 rows x 3 columns]
